# %%
import numpy as np

rng = np.random.default_rng()
rng.random()  # generate a floating point number between 0 and 1

# %timeit int(4*rng.random())  # generate a random integer between 0 and 3
# Out:
# 485 ns ± 25.6 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
# %timeit np.random.randint(0, 4)
# Out:
# 1.94 µs ± 30.4 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
import random

# %timeit random.getrandbits(2)       # generates either 0, 1 2 or 3
# Out:
# 64.3 ns ± 1.14 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)
